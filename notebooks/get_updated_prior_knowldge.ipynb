# %% [markdown]
# # Get updated prior knowledge
# Run this notebook to get update prior knowledge from the knowledge bases of interest: GO, Reactome, and HPO
# The notebook first downloads the updated information from the knowledge bases, then builds the weighted annotation matrix, and, lastly, computes the Gene Information Scores (GIS). If you wish to use the update information, modify the default_dire to 'prior_knowledge_updated' in the Parser.py

# %%
import os

# %%
# add and set directory of the repository here
dire = '/home/mongardi/GIS-weigthed_LASSO'
os.chdir(dire)

# %%
# create new folder in the data directory 
os.mkdir('data/prior_knowledge_updated')

# %%
os.chdir('data/prior_knowledge_updated')

# %%
# get updated GO file
# !wget http://current.geneontology.org/ontology/go.obo
# Out:
# --2024-02-14 15:03:33--  http://current.geneontology.org/ontology/go.obo
# Resolving current.geneontology.org (current.geneontology.org)... 108.156.2.39, 108.156.2.79, 108.156.2.72, ...
# Connecting to current.geneontology.org (current.geneontology.org)|108.156.2.39|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34420328 (33M) [text/obo]
# Saving to: ‘go.obo’
#
# go.obo              100%[===================>]  32.83M  66.9MB/s    in 0.5s
#
# 2024-02-14 15:03:34 (66.9 MB/s) - ‘go.obo’ saved [34420328/34420328]

# %%
# get updated Reactome file
# !wget https://reactome.org/download/current/NCBI2Reactome_All_Levels.txt
# !wget https://reactome.org/download/current/ReactomePathwaysRelation.txt
#!grep 'HSA'  NCBI2Reactome_All_Levels.txt | grep '^[0-9]' | awk  '{print $1  $2 }' > genes_to_pathways_hsa.csv
# !grep 'HSA'  NCBI2Reactome_All_Levels.txt | grep '^[0-9]' | awk  '{print $1 "," $2}'> genes_to_pathways_hsa.csv
# Out:
# --2024-02-14 15:03:34--  https://reactome.org/download/current/ReactomePathwaysRelation.txt
# Resolving reactome.org (reactome.org)... 100.25.71.177
# Connecting to reactome.org (reactome.org)|100.25.71.177|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 592204 (578K) [text/plain]
# Saving to: ‘ReactomePathwaysRelation.txt’
#
# ReactomePathwaysRel 100%[===================>] 578.32K  1.12MB/s    in 0.5s
#
# 2024-02-14 15:03:35 (1.12 MB/s) - ‘ReactomePathwaysRelation.txt’ saved [592204/592204]
#
# grep: NCBI2Reactome_All_Levels.txt: No such file or directory

# %%
# get updated HPO file
# !wget http://purl.obolibrary.org/obo/hp.obo 
# !wget https://purl.obolibrary.org/obo/hp/hpoa/genes_to_phenotype.txt
#!wget https://hpo.jax.org/app/data/ontology/genes_to_disease.txt
# !grep '^[0-9]' genes_to_phenotype.txt | awk '{print $1, $3 }' > genes_to_phenotype_red.txt
# Out:
# --2024-02-14 15:03:37--  http://purl.obolibrary.org/obo/hp.obo
# Resolving purl.obolibrary.org (purl.obolibrary.org)... 104.18.37.59, 172.64.150.197, 2606:4700:4400::ac40:96c5, ...
# Connecting to purl.obolibrary.org (purl.obolibrary.org)|104.18.37.59|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/obophenotype/human-phenotype-ontology/releases/latest/download/hp.obo [following]
# --2024-02-14 15:03:37--  https://github.com/obophenotype/human-phenotype-ontology/releases/latest/download/hp.obo
# Resolving github.com (github.com)... 140.82.121.4
# Connecting to github.com (github.com)|140.82.121.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/obophenotype/human-phenotype-ontology/releases/download/v2024-02-08/hp.obo [following]
# --2024-02-14 15:03:37--  https://github.com/obophenotype/human-phenotype-ontology/releases/download/v2024-02-08/hp.obo
# ...

# %%
os.chdir(dire)
# !python  src/prior_knowledge/utils/create_dag_go.py
# !python  src/prior_knowledge/utils/create_dag_hpo.py
# Out:
# -------------
# GO:0000015
# GO:0005829
# -------------
# -------------
# GO:0000022
# GO:0000070
# -------------
# -------------
# GO:0000022
# GO:0007052
# -------------
# -------------
# GO:0000027
# GO:0042255
# -------------
# -------------
# GO:0000027
# GO:0042273
# -------------
# -------------
# GO:0000028
# GO:0042255
# -------------
# -------------
# GO:0000028
# GO:0042274
# -------------
# -------------
# GO:0000036
# GO:0006633
# -------------
# -------------
# GO:0000054
# GO:0042254
# -------------
# -------------
# GO:0000064
# GO:1903352
# -------------
# -------------
# GO:0000070
# GO:0140014
# -------------
# -------------
# GO:0000073
# GO:0061804
# -------------
# -------------
# GO:0000073
# GO:1905047
# -------------
# -------------
# GO:0000080
# GO:0051329
# -------------
# -------------
# GO:0000083
# GO:0000082
# -------------
# -------------
# GO:0000084
# GO:0051329
# -------------
# -------------
# GO:0000085
# GO:0051329
# -------------
# ...

# %%
# !python  src/prior_knowledge/get_ICstruct_gis_go.py
# !python  src/prior_knowledge/get_ICstruct_gis_reactome.py
# !python  src/prior_knowledge/get_ICstruct_gis_hpo.py

# calculate GIS
# !python  src/prior_knowledge/get_GIS.py
# Out:
# 100%|███████████████████████████████████| 11235/11235 [00:10<00:00, 1106.94it/s]
# 0it [00:00, ?it/s]
# ...
# 100%|███████████████████████████████████| 2629/2629 [00:00<00:00, 195549.22it/s]
# Max depth ontology: 12
# 18484
# 18484
# ...
# 100%|████████████████████████████████████| 18484/18484 [02:44<00:00, 112.50it/s]
# Max depth ontology: 18
# ...
# 100%|███████████████████████████████████| 11235/11235 [00:10<00:00, 1068.83it/s]
# 0it [00:00, ?it/s]
# ...
# 100%|██████████████████████████████████████| 5011/5011 [00:16<00:00, 299.71it/s]
# (20401, 50094)
# (20401, 50094)
# (20158, 65379)
# (20158, 65379)
# (20451, 67989)
# (20451, 67989)
